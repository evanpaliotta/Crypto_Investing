# %% [markdown]
# # Going Live with CCXT

# %% [markdown]
# ### Import Libraries and Dependencies

# %%
# Import libraries and dependencies
import ccxt
import os
import pandas as pd

# %% [markdown]
# ### Import Environment Variables

# %%
# Import environment variables
kraken_public_key = os.getenv('KRAKEN_PUBLIC_KEY')
kraken_secret_key = os.getenv('KRAKEN_SECRET_KEY')

# %% [markdown]
# ### Set Public and Private Keys for Kraken Exchange via the CCXT library

# %%
# Set the public and private keys for the API
exchange = ccxt.kraken({
    'apiKey': kraken_public_key,
    'secret': kraken_secret_key,
})

# %%
type(kraken_public_key)
# Out:
# str

# %%
type(kraken_secret_key)
# Out:
# str

# %% [markdown]
# ### Connect to Kraken and Load Available Cryptocurrency Data

# %%
# Connect to Kraken and load the available cryptocurrencies
crypto_details = exchange.load_markets()

# Import data as a Pandas DataFrame
crypto_df = pd.DataFrame(crypto_details)
crypto_df
# Out:
#                                                       ADA/ETH  \
# active                                                   True
# altname                                                ADAETH
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAETH
# info        {'altname': 'ADAETH', 'wsname': 'ADA/ETH', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 7}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                                ADA/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/EUR  \
# active                                                   True
# altname                                                ADAEUR
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAEUR
# info        {'altname': 'ADAEUR', 'wsname': 'ADA/EUR', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                ADA/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/USD  \
# active                                                   True
# altname                                                ADAUSD
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAUSD
# info        {'altname': 'ADAUSD', 'wsname': 'ADA/USD', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                ADA/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/BTC  \
# active                                                   True
# altname                                                ADAXBT
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAXBT
# info        {'altname': 'ADAXBT', 'wsname': 'ADA/XBT', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 8}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                                ADA/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/ETH  \
# active                                                   True
# altname                                               ALGOETH
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOETH
# info        {'altname': 'ALGOETH', 'wsname': 'ALGO/ETH', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 7}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                               ALGO/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/EUR  \
# active                                                   True
# altname                                               ALGOEUR
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOEUR
# info        {'altname': 'ALGOEUR', 'wsname': 'ALGO/EUR', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                               ALGO/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/USD  \
# active                                                   True
# altname                                               ALGOUSD
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOUSD
# info        {'altname': 'ALGOUSD', 'wsname': 'ALGO/USD', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                               ALGO/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/BTC  \
# active                                                   True
# altname                                               ALGOXBT
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOXBT
# info        {'altname': 'ALGOXBT', 'wsname': 'ALGO/XBT', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 8}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                               ALGO/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ATOM/ETH  \
# active                                                   True
# altname                                               ATOMETH
# base                                                     ATOM
# baseId                                                   ATOM
# darkpool                                                False
# id                                                    ATOMETH
# info        {'altname': 'ATOMETH', 'wsname': 'ATOM/ETH', '...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                               ATOM/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ATOM/EUR  ...  \
# active                                                   True  ...
# altname                                               ATOMEUR  ...
# base                                                     ATOM  ...
# baseId                                                   ATOM  ...
# darkpool                                                False  ...
# id                                                    ATOMEUR  ...
# info        {'altname': 'ATOMEUR', 'wsname': 'ATOM/EUR', '...  ...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...  ...
# maker                                                  0.0016  ...
# percentage                                               True  ...
# precision                           {'amount': 8, 'price': 4}  ...
# quote                                                     EUR  ...
# quoteId                                                  ZEUR  ...
# symbol                                               ATOM/EUR  ...
# taker                                                  0.0026  ...
# tierBased                                                True  ...
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...  ...
#
#                                                       XRP/EUR  \
# active                                                   True
# altname                                                XRPEUR
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZEUR
# info        {'altname': 'XRPEUR', 'wsname': 'XRP/EUR', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                XRP/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       XRP/JPY  \
# active                                                   True
# altname                                                XRPJPY
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZJPY
# info        {'altname': 'XRPJPY', 'wsname': 'XRP/JPY', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     JPY
# quoteId                                                  ZJPY
# symbol                                                XRP/JPY
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       XRP/USD  \
# active                                                   True
# altname                                                XRPUSD
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZUSD
# info        {'altname': 'XRPUSD', 'wsname': 'XRP/USD', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                XRP/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/BTC  \
# active                                                   True
# altname                                                ZECXBT
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECXXBT
# info        {'altname': 'ZECXBT', 'wsname': 'ZEC/XBT', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                                ZEC/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/EUR  \
# active                                                   True
# altname                                                ZECEUR
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECZEUR
# info        {'altname': 'ZECEUR', 'wsname': 'ZEC/EUR', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                ZEC/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/USD  \
# active                                                   True
# altname                                                ZECUSD
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECZUSD
# info        {'altname': 'ZECUSD', 'wsname': 'ZEC/USD', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 2}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                ZEC/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       EUR/USD  \
# active                                                   True
# altname                                                EURUSD
# base                                                      EUR
# baseId                                                   ZEUR
# darkpool                                                False
# id                                                   ZEURZUSD
# info        {'altname': 'EURUSD', 'wsname': 'EUR/USD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                EUR/USD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       GBP/USD  \
# active                                                   True
# altname                                                GBPUSD
# base                                                      GBP
# baseId                                                   ZGBP
# darkpool                                                False
# id                                                   ZGBPZUSD
# info        {'altname': 'GBPUSD', 'wsname': 'GBP/USD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                GBP/USD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       USD/CAD  \
# active                                                   True
# altname                                                USDCAD
# base                                                      USD
# baseId                                                   ZUSD
# darkpool                                                False
# id                                                   ZUSDZCAD
# info        {'altname': 'USDCAD', 'wsname': 'USD/CAD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     CAD
# quoteId                                                  ZCAD
# symbol                                                USD/CAD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       USD/JPY
# active                                                   True
# altname                                                USDJPY
# base                                                      USD
# baseId                                                   ZUSD
# darkpool                                                False
# id                                                   ZUSDZJPY
# info        {'altname': 'USDJPY', 'wsname': 'USD/JPY', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     JPY
# quoteId                                                  ZJPY
# symbol                                                USD/JPY
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
# [17 rows x 179 columns]

# %% [markdown]
# ### List Available Cryptocurrencies for Trading

# %%
# Print column values of DataFrame
print(type(crypto_df.columns.values))
print(crypto_df.columns.values)
print(len(crypto_df.columns.values))
# Out:
# <class 'numpy.ndarray'>
# ['ADA/ETH' 'ADA/EUR' 'ADA/USD' 'ADA/BTC' 'ALGO/ETH' 'ALGO/EUR' 'ALGO/USD'
#  'ALGO/BTC' 'ATOM/ETH' 'ATOM/EUR' 'ATOM/USD' 'ATOM/BTC' 'AUD/JPY'
#  'AUD/USD' 'BAT/ETH' 'BAT/EUR' 'BAT/USD' 'BAT/BTC' 'BCH/AUD' 'BCH/ETH'
#  'BCH/EUR' 'BCH/GBP' 'BCH/USD' 'BCH/USDT' 'BCH/BTC' 'DAI/EUR' 'DAI/USD'
#  'DAI/USDT' 'DASH/EUR' 'DASH/USD' 'DASH/BTC' 'EOS/ETH' 'EOS/EUR' 'EOS/USD'
#  'EOS/BTC' 'ETH/AUD' 'ETH/CHF' 'ETH/DAI' 'ETH/USDC' 'ETH/USDT' 'EUR/AUD'
#  'EUR/CAD' 'EUR/CHF' 'EUR/GBP' 'EUR/JPY' 'GNO/ETH' 'GNO/EUR' 'GNO/USD'
#  'GNO/BTC' 'ICX/ETH' 'ICX/EUR' 'ICX/USD' 'ICX/BTC' 'LINK/ETH' 'LINK/EUR'
#  'LINK/USD' 'LINK/BTC' 'LSK/ETH' 'LSK/EUR' 'LSK/USD' 'LSK/BTC' 'LTC/AUD'
#  'LTC/ETH' 'LTC/GBP' 'LTC/USDT' 'NANO/ETH' 'NANO/EUR' 'NANO/USD'
#  'NANO/BTC' 'OMG/ETH' 'OMG/EUR' 'OMG/USD' 'OMG/BTC' 'OXT/ETH' 'OXT/EUR'
#  'OXT/USD' 'OXT/BTC' 'PAXG/ETH' 'PAXG/EUR' 'PAXG/USD' 'PAXG/BTC'
#  'QTUM/ETH' 'QTUM/EUR' 'QTUM/USD' 'QTUM/BTC' 'SC/ETH' 'SC/EUR' 'SC/USD'
#  'SC/BTC' 'TRX/ETH' 'TRX/EUR' 'TRX/USD' 'TRX/BTC' 'USDC/EUR' 'USD/CHF'
#  'USDC/USD' 'USDC/USDT' 'USDT/AUD' 'USDT/CAD' 'USDT/CHF' 'USDT/EUR'
#  'USDT/GBP' 'USDT/JPY' 'USDT/USD' 'WAVES/ETH' 'WAVES/EUR' 'WAVES/USD'
#  'WAVES/BTC' 'BTC/AUD' 'BTC/CHF' 'BTC/DAI' 'BTC/USDC' 'BTC/USDT'
#  'DOGE/EUR' 'DOGE/USD' 'ETC/ETH' 'ETC/BTC' 'ETC/EUR' 'ETC/USD' 'ETH/BTC'
#  'ETHXBT.d' 'ETH/CAD' 'ETHCAD.d' 'ETH/EUR' 'ETHEUR.d' 'ETH/GBP' 'ETHGBP.d'
#  'ETH/JPY' 'ETHJPY.d' 'ETH/USD' 'ETHUSD.d' 'LTC/BTC' 'LTC/EUR' 'LTC/USD'
#  'MLN/ETH' 'MLN/BTC' 'MLN/EUR' 'MLN/USD' 'REP/ETH' 'REP/BTC' 'REP/EUR'
#  'REP/USD' 'XRP/AUD' 'XRP/ETH' 'XRP/GBP' 'XRP/USDT' 'XTZ/ETH' 'XTZ/EUR'
#  'XTZ/USD' 'XTZ/BTC' 'BTC/CAD' 'XBTCAD.d' 'BTC/EUR' 'XBTEUR.d' 'BTC/GBP'
#  'XBTGBP.d' 'BTC/JPY' 'XBTJPY.d' 'BTC/USD' 'XBTUSD.d' 'DOGE/BTC' 'XLM/BTC'
#  'XLM/EUR' 'XLM/USD' 'XMR/BTC' 'XMR/EUR' 'XMR/USD' 'XRP/BTC' 'XRP/CAD'
#  'XRP/EUR' 'XRP/JPY' 'XRP/USD' 'ZEC/BTC' 'ZEC/EUR' 'ZEC/USD' 'EUR/USD'
#  'GBP/USD' 'USD/CAD' 'USD/JPY']
# 179

# %%
# Show list of available functions for the current exchange (in this case Kraken)
exchange.has
# Out:
# {'loadMarkets': True,
#  'cancelAllOrders': False,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchOrderTrades': 'emulated',
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
#  'fetchTransactions': False,
#  'fetchWithdrawals': True,
#  'privateAPI': True,
#  'publicAPI': True,
#  'withdraw': True,
#  'fetchLedgerEntry': True}

# %% [markdown]
# ### Fetch Historical Data for BTC/USD

# %%
# Fetch daily candlestick bar data from `BTC/USD`
historical_prices = exchange.fetch_ohlcv("LINK/USD", "1d")

# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp     open     high      low    close        volume
# 0    1569283200000  0.00000  0.00000  0.00000  0.00000  0.000000e+00
# 1    1569369600000  0.00000  2.09980  0.00000  1.84791  3.935117e+04
# 2    1569456000000  1.84791  1.85896  1.53188  1.67701  2.760317e+04
# 3    1569542400000  1.67701  1.70165  1.57654  1.69775  1.669466e+04
# 4    1569628800000  1.69775  1.72181  1.65939  1.70000  1.149729e+04
# 5    1569715200000  1.70000  1.84987  1.65849  1.71263  2.510910e+04
# 6    1569801600000  1.71263  1.83149  1.66619  1.77000  2.974853e+04
# 7    1569888000000  1.77000  1.89999  1.75154  1.87504  7.031197e+04
# 8    1569974400000  1.87504  2.08994  1.82001  2.05474  1.111593e+05
# 9    1570060800000  2.05474  2.24936  1.91540  1.94718  8.060644e+04
# 10   1570147200000  1.94718  1.99800  1.88746  1.97625  1.363176e+04
# 11   1570233600000  1.97625  1.98000  1.92110  1.97208  5.743935e+03
# 12   1570320000000  1.97208  2.34053  1.95964  2.19000  3.036103e+04
# 13   1570406400000  2.19000  2.57695  2.11201  2.42500  1.423788e+05
# 14   1570492800000  2.42500  2.67999  2.27699  2.57239  1.016258e+05
# 15   1570579200000  2.57239  2.97986  2.50841  2.81133  1.400310e+05
# 16   1570665600000  2.81133  2.97800  2.49049  2.64707  1.640231e+05
# 17   1570752000000  2.64707  2.80838  2.56658  2.75320  1.195714e+05
# 18   1570838400000  2.75320  2.75320  2.57000  2.58257  7.065113e+04
# 19   1570924800000  2.58257  2.63336  2.43441  2.48750  2.663864e+04
# 20   1571011200000  2.48750  2.67000  2.46180  2.53752  3.808992e+04
# 21   1571097600000  2.53752  2.61206  2.33988  2.38130  4.886607e+04
# 22   1571184000000  2.38130  2.40780  2.19500  2.37009  8.501452e+04
# 23   1571270400000  2.37009  2.48997  2.27569  2.40780  6.067653e+04
# 24   1571356800000  2.40780  2.49531  2.32338  2.35809  4.642989e+04
# 25   1571443200000  2.35809  2.39218  2.30160  2.34097  1.447316e+04
# 26   1571529600000  2.34097  2.44580  2.28230  2.43440  3.249600e+04
# 27   1571616000000  2.43440  2.67350  2.43440  2.63509  1.564890e+05
# 28   1571702400000  2.63509  4.00000  2.54000  2.59191  1.320351e+05
# 29   1571788800000  2.59191  2.69660  2.40000  2.62419  1.765183e+05
# ..             ...      ...      ...      ...      ...           ...
# 262  1591920000000  3.96839  4.16836  3.85000  4.08540  2.755660e+05
# 263  1592006400000  4.08540  4.11816  4.01855  4.10497  6.140000e+04
# 264  1592092800000  4.10497  4.11044  3.91524  3.94645  8.721285e+04
# 265  1592179200000  3.94645  3.98908  3.62754  3.95245  3.758025e+05
# 266  1592265600000  3.95245  4.09664  3.89548  4.04499  2.049958e+05
# 267  1592352000000  4.04499  4.19511  3.95608  4.16905  2.958597e+05
# 268  1592438400000  4.16905  4.24613  4.09500  4.15084  1.827977e+05
# 269  1592524800000  4.15084  4.16476  4.04370  4.08943  2.022061e+05
# 270  1592611200000  4.08943  4.20000  4.06500  4.18117  1.589173e+05
# 271  1592697600000  4.18117  4.19584  4.14027  4.17233  7.976775e+04
# 272  1592784000000  4.17233  4.49000  4.17233  4.48802  3.783513e+05
# 273  1592870400000  4.48802  4.94759  4.43000  4.79449  6.101169e+05
# 274  1592956800000  4.79449  4.94982  4.50000  4.70361  6.265524e+05
# 275  1593043200000  4.70876  4.82792  4.50358  4.81048  2.961885e+05
# 276  1593129600000  4.80767  4.87024  4.63846  4.67721  4.094515e+05
# 277  1593216000000  4.68077  4.68460  4.30665  4.40303  2.741035e+05
# 278  1593302400000  4.40303  4.61636  4.33226  4.56900  1.892598e+05
# 279  1593388800000  4.56895  4.66106  4.43059  4.59954  1.506831e+05
# 280  1593475200000  4.61503  4.65648  4.53897  4.57345  7.090908e+04
# 281  1593561600000  4.57345  4.73500  4.51976  4.70025  2.620766e+05
# 282  1593648000000  4.70441  4.91900  4.58909  4.79433  3.714635e+05
# 283  1593734400000  4.79319  4.88899  4.71003  4.74500  1.451239e+05
# 284  1593820800000  4.74500  4.84732  4.72209  4.81805  9.119021e+04
# 285  1593907200000  4.81805  4.82860  4.61506  4.74967  1.530364e+05
# 286  1593993600000  4.74967  5.47973  4.74000  5.36638  6.879068e+05
# 287  1594080000000  5.36638  5.89874  5.34082  5.71659  8.043334e+05
# 288  1594166400000  5.72657  6.58589  5.60442  6.49288  1.168557e+06
# 289  1594252800000  6.49155  6.49427  5.70003  6.07532  6.726762e+05
# 290  1594339200000  6.07532  6.20451  5.71311  6.13408  4.557464e+05
# 291  1594425600000  6.13408  6.26000  6.13408  6.13986  5.919784e+04
#
# [292 rows x 6 columns]

# %% [markdown]
# ### Convert Epoch Timestamp to Readable Date Format

# %%
# Convert epoch timestamp to date using the `to_datetime` function and `unit` parameter
historical_prices_df["date"] = pd.to_datetime(
    historical_prices_df["timestamp"], unit="ms"
)
historical_prices_df.head()
# Out:
#        timestamp     open     high      low    close        volume       date
# 0  1569283200000  0.00000  0.00000  0.00000  0.00000      0.000000 2019-09-24
# 1  1569369600000  0.00000  2.09980  0.00000  1.84791  39351.171629 2019-09-25
# 2  1569456000000  1.84791  1.85896  1.53188  1.67701  27603.167747 2019-09-26
# 3  1569542400000  1.67701  1.70165  1.57654  1.69775  16694.659541 2019-09-27
# 4  1569628800000  1.69775  1.72181  1.65939  1.70000  11497.285339 2019-09-28

# %% [markdown]
# ### Fetch Latest Data for BTC/USD

# %%
# Fetch current price details for `BTC/USD`
current_price = exchange.fetch_ticker('LINK/USD')

# Delete `info` key-value pair
del current_price['info']

current_price
# Out:
# {'symbol': 'LINK/USD',
#  'timestamp': 1594439730286,
#  'datetime': '2020-07-11T03:55:30.286Z',
#  'high': 6.26,
#  'low': 5.71311,
#  'bid': 6.14384,
#  'bidVolume': None,
#  'ask': 6.15974,
#  'askVolume': None,
#  'vwap': 5.989639,
#  'open': 6.13408,
#  'close': 6.13986,
#  'last': 6.13986,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 474701.2726671,
#  'quoteVolume': 2843289.2561164964}

# %%
# Import data as a Pandas DataFrame
current_price_df = pd.DataFrame(current_price, index=[0])
current_price_df
# Out:
#      symbol      timestamp                  datetime  high      low      bid  \
# 0  LINK/USD  1594439730286  2020-07-11T03:55:30.286Z  6.26  5.71311  6.14384
#
#   bidVolume      ask askVolume      vwap     open    close     last  \
# 0      None  6.15974      None  5.989639  6.13408  6.13986  6.13986
#
#   previousClose change percentage average     baseVolume   quoteVolume
# 0          None   None       None    None  474701.272667  2.843289e+06

# %%
# Fetch balance
exchange.fetch_balance()
# Out:
# {'info': {}, 'free': {}, 'used': {}, 'total': {}}

# %%
# Fetch status
exchange.fetch_status()
# Out:
# {'status': 'ok', 'updated': 1594439759000, 'eta': None, 'url': None}

# %%
# Fetch open orders
# exchange.fetch_open_orders()
